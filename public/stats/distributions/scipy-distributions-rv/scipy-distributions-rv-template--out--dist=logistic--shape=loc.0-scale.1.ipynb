# %% [markdown]
# **Execution:**
#
# * Started: 2018-03-22 14:30:56 GMT
# * Ended: 2018-03-22 14:31:10 GMT
#
# **Duration:** 13.4 seconds.
#
# **Autogenerated from:** [scipy-distributions-rv-template.ipynb](in_path)

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy as np
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
import matplotlib as mpl
import seabornextends as snsexts
import faker
from faker import utils
from seabornextends import plots, retouch
from seabornextends.retouch import grid, ax, fig

# %%
sns.set_style('whitegrid')
mpl.rcParams['grid.color'] = '0.95'
mpl.rcParams['grid.alpha'] = 0.8
mpl.rcParams['font.family'] = 'Roboto Condensed'

# %% [markdown]
# # Develop intuitive understanding of common distributions

# %% [markdown]
# ## Parameters

# %%
# default parameters for this template
# (these are overriden during dynamic notebook execution)
dist_family = 'norm'
kind = 'continuous'

# default shape
default_shape_kws = {'loc': 0, 'scale': 1}

# grid of shapes
shape_grid = {
    'loc': [2, 4, 6],
    'scale': [3, 6, 9]
}

# for plotting
row = 'loc'
col = 'scale'
sharex = True
sharey = True
kde = True

# params for creating evenly spaced probabilities
LO_PROB = 0.001
HI_PROB = 0.999
n_prob_linspace = 1000

# common lo/hi probabilities
lo_p = 0.025
hi_p = 0.975

# list of common probabilities
common_probs = [0.01, 0.025, 0.05, 0.1, 0.4, 0.5, 0.6, 0.9, 0.95, 0.975, 0.99]

# %%
# cell inserted during automated execution with new args.
dist_family = 'logistic'
kind = 'continuous'
default_shape_kws = {'loc': 0, 'scale': 1}
shape_grid = {'loc': [20, 30, 40], 'scale': [5, 10, 15]}
row = 'loc'
col = 'scale'

# %% [markdown]
# ## Get distribution function from scipy

# %%
dist_func = getattr(stats, dist_family)
dist_func

# %% [markdown]
# ## Compare this distribution in different shapes

# %% [markdown]
# Generate random samples from this distribution in different shapes (of size `iters` each):

# %%
df = faker.utils.stacked_from_function(func=getattr(dist_func, 'rvs'),
                                       param_grid=shape_grid,
                                       col_names=['random_value'],
                                       iters=10000,
                                       seed=12345)

# %%
grid = snsexts.plots.distplot(a='random_value',
                              data=df,
                              row=row,
                              col=col,
                              sharex=sharex,
                              sharey=sharey,
                              distplot_kws={'hist': True, 'kde': kde})
retoucher = retouch.grid.FacetGridRetoucher(grid)
retoucher.fig.set_dpi(300)

# %% [markdown]
# ## Instantiate a distribution

# %%
mydist = dist_func(**default_shape_kws)
mydist

# %% [markdown]
# In order to make this notebook work for both continuous and discrete distributions
# we create a common alias for PDF/PMF.

# %%
if kind == 'continuous':
    pf = mydist.pdf
    pfname = 'PDF'
    pfdesc = 'Probability Density Function'
    logpf = mydist.logpdf
    logpfname = 'Log PDF'
    logpfdesc = 'Log Probability Density Function'
    
elif kind == 'discrete':
    pf = mydist.pmf
    pfname = 'PMF'
    pfdesc = 'Probability Mass Function'
    
    logpf = mydist.logpmf
    logpfname = 'Log PMF'
    logpfdesc = 'Log Probability Mass Function'

# %% [markdown]
# Moments:

# %%
mean, var, skew, kurt = mydist.stats(moments='mvsk')
print("mean: ", mean)
print("var: ", var)
print("skew: ", skew)
print("kurt: ", kurt)
# Out:
# mean:  0.0
# var:  3.289868133696453
# skew:  0.0
# kurt:  1.2

# %% [markdown]
# ### Generate evenly spaced probabilities

# %% [markdown]
# Generate a list of evenly spaced probabilities:

# %%
prob_linspace = np.linspace(start=LO_PROB, stop=HI_PROB, num=n_prob_linspace)
prob_linspace[0:5], prob_linspace[-5:]
# Out:
# (array([0.001   , 0.001999, 0.002998, 0.003997, 0.004996]),
#  array([0.995004, 0.996003, 0.997002, 0.998001, 0.999   ]))

# %% [markdown]
# Get _quantiles_ corresponding to probabilities in `prob_linspace`

# %%
quantiles = mydist.ppf(prob_linspace)
quantiles[0:5], quantiles[-5:]
# Out:
# (array([-6.90675478, -6.21310772, -5.80680805, -5.51820694, -5.29410997]),
#  array([5.29410997, 5.51820694, 5.80680805, 6.21310772, 6.90675478]))

# %% [markdown]
# ## Generate random numbers from this distribution

# %%
rands = mydist.rvs(size=100000)
rands[0:5]
# Out:
# array([ 1.32425901,  1.27663323, -1.9260064 , -0.82881456,  1.2410782 ])

# %%
ax = sns.distplot(rands)
ax.axvline(np.mean(rands), label='mean: {0:.5f}'.format(np.mean(rands)), color='C3')
ax.axvline(np.median(rands), label='median: {0:.5f}'.format(np.median(rands)), color='C3', ls='dashed')
ax.axvline(mydist.mean(), label='mean of frozen dist: {0:.5f}'.format(mydist.mean()), color='C4')
plt.legend(bbox_to_anchor=(1, 1), loc='upper left')
plt.gcf().set_dpi(150)

# %% [markdown]
# ## Probabilty Density Function / Probability Mass Function

# %% [markdown]
# Take a `quantile` as input and return a _point evaluated_ `probability`.
#
# **NOTE**: for normal distribution with mean different to 0 and std different to 1, quantile is a value x (e.g. 1160) _and not_ the standardised version of that value.
#
# To be a **valid pdf/pmf**, a function must satisfy:
# * It must be larger than or equal to zero everywhere (a value must be possible).
# * The total area under it must be one.

# %%
probs = common_probs
for p in probs:
    print("{n} evaluated at quantile {q:.3f} -- which marks {cdf:.3f} CDF probability in distribution -- is {logpf:.3f} (evaluated at that point only).".format(
        q=mydist.ppf(p),
        n=pfname,
        cdf=mydist.cdf(mydist.ppf(p)),
        logpf=pf(mydist.ppf(p))))
# Out:
# PDF evaluated at quantile -4.595 -- which marks 0.010 CDF probability in distribution -- is 0.010 (evaluated at that point only).
# PDF evaluated at quantile -3.664 -- which marks 0.025 CDF probability in distribution -- is 0.024 (evaluated at that point only).
# PDF evaluated at quantile -2.944 -- which marks 0.050 CDF probability in distribution -- is 0.048 (evaluated at that point only).
# PDF evaluated at quantile -2.197 -- which marks 0.100 CDF probability in distribution -- is 0.090 (evaluated at that point only).
# PDF evaluated at quantile -0.405 -- which marks 0.400 CDF probability in distribution -- is 0.240 (evaluated at that point only).
# PDF evaluated at quantile 0.000 -- which marks 0.500 CDF probability in distribution -- is 0.250 (evaluated at that point only).
# PDF evaluated at quantile 0.405 -- which marks 0.600 CDF probability in distribution -- is 0.240 (evaluated at that point only).
# PDF evaluated at quantile 2.197 -- which marks 0.900 CDF probability in distribution -- is 0.090 (evaluated at that point only).
# PDF evaluated at quantile 2.944 -- which marks 0.950 CDF probability in distribution -- is 0.048 (evaluated at that point only).
# PDF evaluated at quantile 3.664 -- which marks 0.975 CDF probability in distribution -- is 0.024 (evaluated at that point only).
# PDF evaluated at quantile 4.595 -- which marks 0.990 CDF probability in distribution -- is 0.010 (evaluated at that point only).

# %% [markdown]
# We evaluate a list of quantiles and return their **probability density function estimate** (point-estimates only).
#
# In the standard normal, quantiles at the extremes of the distribution have very low probability while quantiles in the middle of the distribution have very high probability.

# %%
estimates = pf(mydist.ppf(prob_linspace))

# %%
mydist.ppf(prob_linspace)[0:5], estimates[0:5]
# Out:
# (array([-6.90675478, -6.21310772, -5.80680805, -5.51820694, -5.29410997]),
#  array([0.000999  , 0.001995  , 0.00298901, 0.00398102, 0.00497104]))

# %%
mydist.ppf(prob_linspace)[-5:], estimates[-5:]
# Out:
# (array([5.29410997, 5.51820694, 5.80680805, 6.21310772, 6.90675478]),
#  array([0.00497104, 0.00398102, 0.00298901, 0.001995  , 0.000999  ]))

# %%
# plot
fig, ax = plt.subplots(1, 1)

# function
ax.plot(mydist.ppf(prob_linspace),
        pf(mydist.ppf(prob_linspace)),
        lw=3,
        alpha=0.6,
        color='black',
        label='{0} {1}'.format(dist_family, pfname))

# lo_p

ax.vlines(x=mydist.ppf(lo_p),
          ymin=0,
          ymax=pf(mydist.ppf(lo_p)),
          colors='C3',
          alpha=1,
          label='point probability estimate for quantile {q:.3f} is {p:.3f}'.format(p=pf(mydist.ppf(lo_p)),
                                                                                    q=mydist.ppf(lo_p)))

ax.fill_between(x=mydist.ppf(prob_linspace[np.where((prob_linspace >= LO_PROB) &
                                                    (prob_linspace <= lo_p))]),
                y1=pf(mydist.ppf(prob_linspace[np.where((prob_linspace >= LO_PROB) &
                                                        (prob_linspace <= lo_p))])),
                color='C3',
                alpha=0.1)

# hi_p
ax.vlines(x=mydist.ppf(hi_p),
          ymin=0,
          ymax=pf(mydist.ppf(hi_p)),
          color='C0',
          alpha=1,
          label='point probability estimate for quantile {q:.3f} is {p:.3f}'.format(p=pf(mydist.ppf(hi_p)),
                                                                                    q=mydist.ppf(hi_p)))


ax.fill_between(x=mydist.ppf(prob_linspace[np.where((prob_linspace >= hi_p) &
                                                    (prob_linspace <= HI_PROB))]),
                y1=pf(mydist.ppf(prob_linspace[np.where((prob_linspace >= hi_p) &
                                                        (prob_linspace <= HI_PROB))])),
                color='C0',
                alpha=0.1)

plt.legend(bbox_to_anchor=(1, 1), loc='upper left')
plt.gcf().set_dpi(150)

# %% [markdown]
# ## Log Probabilty Density Function / Probability Mass Function

# %%
probs = common_probs
for p in probs:
    print("{n} evaluated at quantile {q:.3f} -- which marks {cdf:.3f} CDF probability in distribution -- is {logpf:.3f} (evaluated at that point only).".format(
        q=mydist.ppf(p),
        n=logpfname,
        cdf=mydist.cdf(mydist.ppf(p)),
        logpf=logpf(mydist.ppf(p))))
# Out:
# Log PDF evaluated at quantile -4.595 -- which marks 0.010 CDF probability in distribution -- is -4.615 (evaluated at that point only).
# Log PDF evaluated at quantile -3.664 -- which marks 0.025 CDF probability in distribution -- is -3.714 (evaluated at that point only).
# Log PDF evaluated at quantile -2.944 -- which marks 0.050 CDF probability in distribution -- is -3.047 (evaluated at that point only).
# Log PDF evaluated at quantile -2.197 -- which marks 0.100 CDF probability in distribution -- is -2.408 (evaluated at that point only).
# Log PDF evaluated at quantile -0.405 -- which marks 0.400 CDF probability in distribution -- is -1.427 (evaluated at that point only).
# Log PDF evaluated at quantile 0.000 -- which marks 0.500 CDF probability in distribution -- is -1.386 (evaluated at that point only).
# Log PDF evaluated at quantile 0.405 -- which marks 0.600 CDF probability in distribution -- is -1.427 (evaluated at that point only).
# Log PDF evaluated at quantile 2.197 -- which marks 0.900 CDF probability in distribution -- is -2.408 (evaluated at that point only).
# Log PDF evaluated at quantile 2.944 -- which marks 0.950 CDF probability in distribution -- is -3.047 (evaluated at that point only).
# Log PDF evaluated at quantile 3.664 -- which marks 0.975 CDF probability in distribution -- is -3.714 (evaluated at that point only).
# Log PDF evaluated at quantile 4.595 -- which marks 0.990 CDF probability in distribution -- is -4.615 (evaluated at that point only).

# %%
estimates = logpf(mydist.ppf(prob_linspace))

# %%
mydist.ppf(prob_linspace)[0:5], estimates[0:5]
# Out:
# (array([-6.90675478, -6.21310772, -5.80680805, -5.51820694, -5.29410997]),
#  array([-6.90875578, -6.21710972, -5.81281305, -5.52621696, -5.30412701]))

# %%
mydist.ppf(prob_linspace)[-5:], estimates[-5:]
# Out:
# (array([5.29410997, 5.51820694, 5.80680805, 6.21310772, 6.90675478]),
#  array([-5.30412701, -5.52621696, -5.81281305, -6.21710972, -6.90875578]))

# %%
# plot
fig, ax = plt.subplots(1, 1)

# function
ax.plot(mydist.ppf(prob_linspace),
        logpf(mydist.ppf(prob_linspace)),
        lw=3,
        alpha=0.6,
        color='black',
        label='{0} {1}'.format(dist_family, pfname))

# lo_p

ax.vlines(x=mydist.ppf(lo_p),
          ymin=0,
          ymax=logpf(mydist.ppf(lo_p)),
          colors='C3',
          alpha=1,
          label='point probability estimate for quantile {q:.3f} is {p:.3f}'.format(p=logpf(mydist.ppf(lo_p)),
                                                                                    q=mydist.ppf(lo_p)))

ax.fill_between(x=mydist.ppf(prob_linspace[np.where((prob_linspace >= LO_PROB) &
                                                    (prob_linspace <= lo_p))]),
                y1=logpf(mydist.ppf(prob_linspace[np.where((prob_linspace >= LO_PROB) &
                                                        (prob_linspace <= lo_p))])),
                color='C3',
                alpha=0.1)

# hi_p
ax.vlines(x=mydist.ppf(hi_p),
          ymin=0,
          ymax=logpf(mydist.ppf(hi_p)),
          color='C0',
          alpha=1,
          label='point probability estimate for quantile {q:.3f} is {p:.3f}'.format(p=logpf(mydist.ppf(hi_p)),
                                                                                    q=mydist.ppf(hi_p)))


ax.fill_between(x=mydist.ppf(prob_linspace[np.where((prob_linspace >= hi_p) &
                                                    (prob_linspace <= HI_PROB))]),
                y1=logpf(mydist.ppf(prob_linspace[np.where((prob_linspace >= hi_p) &
                                                        (prob_linspace <= HI_PROB))])),
                color='C0',
                alpha=0.1)

plt.legend(bbox_to_anchor=(1, 1), loc='upper left')
plt.gcf().set_dpi(150)

# %% [markdown]
# ## PPF (Percent Point Function or Quantile Function)

# %% [markdown]
# Take a _lower tail_ `probability` as input and return a `quantile` (inverse of `CDF`).
#
# It answers questions such as `What is the value below which 97.5% of distribution falls under?`

# %%
probs = [0.025, 0.5, 0.975]
for p in probs:
     print("Quantile corresponding to {p} lower tail probability is {q:.3f} ({p:.1%} of values are lower than or equal to {q:.3f})".format(
         p=p,
         q=mydist.ppf(p)))
# Out:
# Quantile corresponding to 0.025 lower tail probability is -3.664 (2.5% of values are lower than or equal to -3.664)
# Quantile corresponding to 0.5 lower tail probability is 0.000 (50.0% of values are lower than or equal to 0.000)
# Quantile corresponding to 0.975 lower tail probability is 3.664 (97.5% of values are lower than or equal to 3.664)

# %% [markdown]
# Calculate quantiles corresponding to list of _lower tail_ probabilities:

# %%
estimates = mydist.ppf(prob_linspace)

# %%
prob_linspace[0:5], estimates[0:5]
# Out:
# (array([0.001   , 0.001999, 0.002998, 0.003997, 0.004996]),
#  array([-6.90675478, -6.21310772, -5.80680805, -5.51820694, -5.29410997]))

# %%
prob_linspace[-5:], estimates[-5:]
# Out:
# (array([0.995004, 0.996003, 0.997002, 0.998001, 0.999   ]),
#  array([5.29410997, 5.51820694, 5.80680805, 6.21310772, 6.90675478]))

# %% [markdown]
# Quantiles of common lower tail probabilities:

# %%
probs = common_probs
for p in probs:
     print("Quantile corresponding to {p} lower tail probability is {q:.3f} ({p:.1%} of values are lower than or equal to {q:.3f})".format(
         p=p,
         q=mydist.ppf(p)))
# Out:
# Quantile corresponding to 0.01 lower tail probability is -4.595 (1.0% of values are lower than or equal to -4.595)
# Quantile corresponding to 0.025 lower tail probability is -3.664 (2.5% of values are lower than or equal to -3.664)
# Quantile corresponding to 0.05 lower tail probability is -2.944 (5.0% of values are lower than or equal to -2.944)
# Quantile corresponding to 0.1 lower tail probability is -2.197 (10.0% of values are lower than or equal to -2.197)
# Quantile corresponding to 0.4 lower tail probability is -0.405 (40.0% of values are lower than or equal to -0.405)
# Quantile corresponding to 0.5 lower tail probability is 0.000 (50.0% of values are lower than or equal to 0.000)
# Quantile corresponding to 0.6 lower tail probability is 0.405 (60.0% of values are lower than or equal to 0.405)
# Quantile corresponding to 0.9 lower tail probability is 2.197 (90.0% of values are lower than or equal to 2.197)
# Quantile corresponding to 0.95 lower tail probability is 2.944 (95.0% of values are lower than or equal to 2.944)
# Quantile corresponding to 0.975 lower tail probability is 3.664 (97.5% of values are lower than or equal to 3.664)
# Quantile corresponding to 0.99 lower tail probability is 4.595 (99.0% of values are lower than or equal to 4.595)

# %%
# plot
fig, ax = plt.subplots(1, 1)

# function
ax.plot(mydist.ppf(prob_linspace),
        prob_linspace,
        lw=3,
        alpha=0.6,
        color='black',
        label='{0} ppf'.format(dist_family))

# lo_p
ax.vlines(x=mydist.ppf(lo_p),
          ymin=0,
          ymax=lo_p,
          colors='C3',
          alpha=1,
          label='quantile for which {p:.1%} values are likely to be lower than or equal to is {q:.3f}'.format(
              p=lo_p,
              q=mydist.ppf(lo_p)))




ax.fill_between(x=mydist.ppf(prob_linspace[np.where((prob_linspace >= LO_PROB) &
                                                    (prob_linspace <= lo_p))]),
                y1=mydist.cdf(mydist.ppf(prob_linspace[np.where((prob_linspace >= LO_PROB) &
                                                                (prob_linspace <= lo_p))])),
                color='C3',
                alpha=0.1)

# hi_p
ax.vlines(x=mydist.ppf(hi_p),
          ymin=0,
          ymax=hi_p,
          color='C0',
          alpha=1,
          label='quantile for which {p:.1%} values are likely to be lower than or equal to is {q:.3f}'.format(
              p=hi_p,
              q=mydist.ppf(hi_p)))




ax.fill_between(x=mydist.ppf(prob_linspace[np.where((prob_linspace >= LO_PROB) &
                                                    (prob_linspace <= hi_p))]),
                y1=mydist.cdf(mydist.ppf(prob_linspace[np.where((prob_linspace >= LO_PROB) &
                                                                (prob_linspace <= hi_p))])),
                color='C0',
                alpha=0.1)

plt.legend(bbox_to_anchor=(1, 1), loc='upper left')
plt.gcf().set_dpi(150)

# %% [markdown]
# ## ISF (Inverse Survival Function)

# %% [markdown]
# Take an _upper tail_ `probability` as input and returns a `quantile` (inverse of `SF`).
#
# It answers questions such as `What is the value above which 97.5% of distribution falls above?`

# %%
probs = [0.025, 0.5, 0.975]
for p in probs:
     print("Quantile corresponding to {p} upper tail probability is {q:.3f} ({p:.1%} of values are greater than {q:.3f})".format(
         p=p,
         q=mydist.isf(p)))
# Out:
# Quantile corresponding to 0.025 upper tail probability is 3.664 (2.5% of values are greater than 3.664)
# Quantile corresponding to 0.5 upper tail probability is 0.000 (50.0% of values are greater than 0.000)
# Quantile corresponding to 0.975 upper tail probability is -3.664 (97.5% of values are greater than -3.664)

# %% [markdown]
# Calculate quantiles corresponding to list of _upper tail_ probabilities:

# %%
estimates = mydist.isf(prob_linspace)

# %%
prob_linspace[0:5], estimates[0:5]
# Out:
# (array([0.001   , 0.001999, 0.002998, 0.003997, 0.004996]),
#  array([6.90675478, 6.21310772, 5.80680805, 5.51820694, 5.29410997]))

# %%
prob_linspace[-5:], estimates[-5:]
# Out:
# (array([0.995004, 0.996003, 0.997002, 0.998001, 0.999   ]),
#  array([-5.29410997, -5.51820694, -5.80680805, -6.21310772, -6.90675478]))

# %% [markdown]
# Quantiles of common upper tail probabilities:

# %%
probs = common_probs
for p in probs:
     print("Quantile corresponding to {p} upper tail probability is {q:.3f} ({p:.1%} of values are greater than {q:.3f})".format(
         p=p,
         q=mydist.isf(p)))
# Out:
# Quantile corresponding to 0.01 upper tail probability is 4.595 (1.0% of values are greater than 4.595)
# Quantile corresponding to 0.025 upper tail probability is 3.664 (2.5% of values are greater than 3.664)
# Quantile corresponding to 0.05 upper tail probability is 2.944 (5.0% of values are greater than 2.944)
# Quantile corresponding to 0.1 upper tail probability is 2.197 (10.0% of values are greater than 2.197)
# Quantile corresponding to 0.4 upper tail probability is 0.405 (40.0% of values are greater than 0.405)
# Quantile corresponding to 0.5 upper tail probability is 0.000 (50.0% of values are greater than 0.000)
# Quantile corresponding to 0.6 upper tail probability is -0.405 (60.0% of values are greater than -0.405)
# Quantile corresponding to 0.9 upper tail probability is -2.197 (90.0% of values are greater than -2.197)
# Quantile corresponding to 0.95 upper tail probability is -2.944 (95.0% of values are greater than -2.944)
# Quantile corresponding to 0.975 upper tail probability is -3.664 (97.5% of values are greater than -3.664)
# Quantile corresponding to 0.99 upper tail probability is -4.595 (99.0% of values are greater than -4.595)

# %%
# plot
fig, ax = plt.subplots(1, 1)

# function
ax.plot(mydist.isf(prob_linspace),
        prob_linspace,
        lw=3,
        alpha=0.6,
        color='black',
        label='{0} isf'.format(dist_family))

# hi_p
ax.vlines(x=mydist.isf(hi_p),
          ymin=0,
          ymax=hi_p,
          color='C3',
          alpha=1,
          label='quantile for which {p:.1%} values are likely to be greater than is {q:.3f}'.format(
              p=hi_p,
              q=mydist.isf(hi_p)))


ax.fill_between(x=mydist.ppf(prob_linspace[np.where((prob_linspace >= LO_PROB) &
                                                    (prob_linspace <= hi_p))]),
                y1=mydist.sf(mydist.ppf(prob_linspace[np.where((prob_linspace >= LO_PROB) &
                                                               (prob_linspace <= hi_p))])),
                color='C3',
                alpha=0.1)

# lo_p
ax.vlines(x=mydist.isf(lo_p),
          ymin=0,
          ymax=lo_p,
          colors='C0',
          alpha=1,
          label='quantile for which {p:.1%} values are likely to be greater than is {q:.3f}'.format(
              p=lo_p,
              q=mydist.isf(lo_p)))



ax.fill_between(x=mydist.ppf(prob_linspace[np.where((prob_linspace >= LO_PROB) &
                                                    (prob_linspace <= lo_p))]),
                y1=mydist.sf(mydist.ppf(prob_linspace[np.where((prob_linspace >= LO_PROB) &
                                                               (prob_linspace <= lo_p))])),
                color='C0',
                alpha=0.1)


plt.legend(bbox_to_anchor=(1, 1), loc='upper left')
plt.gcf().set_dpi(150)

# %% [markdown]
# ## CDF (Cumulative Density Function)

# %% [markdown]
# Take a `quantile` as input and return a `probability`.
#
# CDF returns the `probability` that the random variable is *less than or equal to some value* (a `quantile`)

# %%
probs = common_probs
for p in probs:
    print("Probability that a random variable is *less or equal than* {q:.3f} quantile is {cdf:.3f}.".format(
        q=mydist.ppf(p),
        cdf=mydist.cdf(mydist.ppf(p))))
# Out:
# Probability that a random variable is *less or equal than* -4.595 quantile is 0.010.
# Probability that a random variable is *less or equal than* -3.664 quantile is 0.025.
# Probability that a random variable is *less or equal than* -2.944 quantile is 0.050.
# Probability that a random variable is *less or equal than* -2.197 quantile is 0.100.
# Probability that a random variable is *less or equal than* -0.405 quantile is 0.400.
# Probability that a random variable is *less or equal than* 0.000 quantile is 0.500.
# Probability that a random variable is *less or equal than* 0.405 quantile is 0.600.
# Probability that a random variable is *less or equal than* 2.197 quantile is 0.900.
# Probability that a random variable is *less or equal than* 2.944 quantile is 0.950.
# Probability that a random variable is *less or equal than* 3.664 quantile is 0.975.
# Probability that a random variable is *less or equal than* 4.595 quantile is 0.990.

# %% [markdown]
# We evaluate a list of quantiles and return their **cumulative density function** probability.

# %%
estimates = mydist.cdf(mydist.ppf(prob_linspace))

# %%
mydist.ppf(prob_linspace)[0:5], estimates[0:5]
# Out:
# (array([-6.90675478, -6.21310772, -5.80680805, -5.51820694, -5.29410997]),
#  array([0.001   , 0.001999, 0.002998, 0.003997, 0.004996]))

# %%
mydist.ppf(prob_linspace)[-5:], estimates[-5:]
# Out:
# (array([5.29410997, 5.51820694, 5.80680805, 6.21310772, 6.90675478]),
#  array([0.995004, 0.996003, 0.997002, 0.998001, 0.999   ]))

# %%
# plot
fig, ax = plt.subplots(1, 1)

# function
ax.plot(mydist.ppf(prob_linspace),
        mydist.cdf(mydist.ppf(prob_linspace)),
        lw=3,
        alpha=0.6,
        color='black',
        label='{0} cdf'.format(dist_family))

# lo_p

ax.vlines(x=mydist.ppf(lo_p),
          ymin=0,
          ymax=mydist.cdf(mydist.ppf(lo_p)),
          colors='C3',
          alpha=1,
          label='probability that a random variable\n from this distribution is lower than quantile {q:.3f} is {p:.1%}'.format(
              p=mydist.cdf(mydist.ppf(lo_p)),
              q=mydist.ppf(lo_p)))



ax.fill_between(x=mydist.ppf(prob_linspace[np.where((prob_linspace >= LO_PROB) &
                                                    (prob_linspace <= lo_p))]),
                y1=mydist.cdf(mydist.ppf(prob_linspace[np.where((prob_linspace >= LO_PROB) &
                                                                (prob_linspace <= lo_p))])),
                color='C3',
                alpha=0.1)

# hi_p
ax.vlines(x=mydist.ppf(hi_p),
          ymin=0,
          ymax=mydist.cdf(mydist.ppf(hi_p)),
          color='C0',
          alpha=1,
          label='probability that a random variable\n from this distribution is lower than quantile {q:.3f} is {p:.1%}'.format(
              p=mydist.cdf(mydist.ppf(hi_p)),
              q=mydist.ppf(hi_p)))



ax.fill_between(x=mydist.ppf(prob_linspace[np.where((prob_linspace >= LO_PROB) &
                                                    (prob_linspace <= hi_p))]),
                y1=mydist.cdf(mydist.ppf(prob_linspace[np.where((prob_linspace >= LO_PROB) &
                                                                (prob_linspace <= hi_p))])),
                color='C0',
                alpha=0.1)

plt.legend(bbox_to_anchor=(1, 1), loc='upper left')
plt.gcf().set_dpi(150)

# %% [markdown]
# ## SF (Survival Function)

# %% [markdown]
# Take a `quantile` as input and return a `probability`.
#
# SF returns the `probability` that the random variable is *greater than some value* (a `quantile`)

# %%
probs = common_probs
for p in probs:
    print("Probability that a random variable is *greater than* {q:.3f} quantile is {sf:.3f}.".format(
        q=mydist.ppf(p),
        sf=mydist.sf(mydist.ppf(p))))
# Out:
# Probability that a random variable is *greater than* -4.595 quantile is 0.990.
# Probability that a random variable is *greater than* -3.664 quantile is 0.975.
# Probability that a random variable is *greater than* -2.944 quantile is 0.950.
# Probability that a random variable is *greater than* -2.197 quantile is 0.900.
# Probability that a random variable is *greater than* -0.405 quantile is 0.600.
# Probability that a random variable is *greater than* 0.000 quantile is 0.500.
# Probability that a random variable is *greater than* 0.405 quantile is 0.400.
# Probability that a random variable is *greater than* 2.197 quantile is 0.100.
# Probability that a random variable is *greater than* 2.944 quantile is 0.050.
# Probability that a random variable is *greater than* 3.664 quantile is 0.025.
# Probability that a random variable is *greater than* 4.595 quantile is 0.010.

# %% [markdown]
# We evaluate a list of quantiles and return their **survival function** probability.

# %%
estimates = mydist.sf(mydist.ppf(prob_linspace))

# %%
mydist.ppf(prob_linspace)[0:5], estimates[0:5]
# Out:
# (array([-6.90675478, -6.21310772, -5.80680805, -5.51820694, -5.29410997]),
#  array([0.999   , 0.998001, 0.997002, 0.996003, 0.995004]))

# %%
mydist.ppf(prob_linspace)[-5:], estimates[-5:]
# Out:
# (array([5.29410997, 5.51820694, 5.80680805, 6.21310772, 6.90675478]),
#  array([0.004996, 0.003997, 0.002998, 0.001999, 0.001   ]))

# %%
# plot
fig, ax = plt.subplots(1, 1)

# function
ax.plot(mydist.ppf(prob_linspace),
        mydist.sf(mydist.ppf(prob_linspace)),
        lw=3,
        alpha=0.6,
        color='black',
        label='{0} sf'.format(dist_family))

# lo_p

ax.vlines(x=mydist.ppf(lo_p),
          ymin=0,
          ymax=mydist.sf(mydist.ppf(lo_p)),
          colors='C3',
          alpha=1,
          label='probability that a random variable\n from this distribution is greater than quantile {q:.3f} is {p:.1%}'.format(
              p=mydist.sf(mydist.ppf(lo_p)),
              q=mydist.ppf(lo_p)))



ax.fill_between(x=mydist.ppf(prob_linspace[np.where((prob_linspace >= lo_p) &
                                                    (prob_linspace <= HI_PROB))]),
                y1=mydist.sf(mydist.ppf(prob_linspace[np.where((prob_linspace >= lo_p) &
                                                               (prob_linspace <= HI_PROB))])),
                color='C3',
                alpha=0.1)

# hi_p
ax.vlines(x=mydist.ppf(hi_p),
          ymin=0,
          ymax=mydist.sf(mydist.ppf(hi_p)),
          color='C0',
          alpha=1,
          label='probability that a random variable\n from this distribution is greater than quantile {q:.3f} is {p:.1%}'.format(
              p=mydist.sf(mydist.ppf(hi_p)),
              q=mydist.ppf(hi_p)))



ax.fill_between(x=mydist.ppf(prob_linspace[np.where((prob_linspace >= hi_p) &
                                                    (prob_linspace <= HI_PROB))]),
                y1=mydist.sf(mydist.ppf(prob_linspace[np.where((prob_linspace >= hi_p) &
                                                               (prob_linspace <= HI_PROB))])),
                color='C0',
                alpha=0.1)

plt.legend(bbox_to_anchor=(1, 1), loc='upper left')
plt.gcf().set_dpi(150)

# %% [markdown]
# ## Variance of sample means

# %% [markdown]
# We treat the sample mean as a random variable in itself which has its own distribution. Central limit theorem shows that the mean of this distribution converges towards the population mean from which we drew the sample as the sample size increases.

# %%
n_samples = 1000
sample_size = 16

# %% [markdown]
# ### Sampling distribution of the mean for a _single_ distribution shape

# %% [markdown]
# Draw `n_samples` random samples of size `sample_size`:

# %%
data = faker.utils.from_function(func=mydist.rvs,
                                 func_kws={'size': sample_size},
                                 func_seed_arg='random_state',
                                 iters=n_samples)

print("data.shape: ", data.shape)
data[0:2]
# Out:
# data.shape:  (1000, 16)
# array([[-7.51360517e-01, -1.31350903e+00,  1.17275324e+00,
#          2.79897516e+00,  4.60120448e+00, -3.33265241e-01,
#          2.94155665e+00, -2.52756750e+00,  1.10151152e-03,
#         -3.30580135e+00,  3.50657046e-01, -3.21869340e-01,
#         -1.84058332e+00, -2.15161067e+00,  2.98932880e+00,
#         -1.07288445e+00],
#        [-1.88573180e+00,  9.38187626e-01, -7.54500944e-01,
#          1.63396524e-01,  4.10871155e-01, -3.98423317e-01,
#         -1.25688105e+00,  1.20251652e-01, -5.39597642e-01,
#          1.22210797e+00, -5.24588433e-01, -3.31919090e-01,
#          1.57749922e+00,  3.10042137e+00,  1.20146043e+00,
#          1.64308432e+00]])

# %% [markdown]
# Calculate the mean for each sample drawn:

# %%
sample_means = np.mean(data, axis=1)
print("sample_means.shape: ", sample_means.shape)
sample_means[0:10]
# Out:
# sample_means.shape:  (1000,)
# array([ 0.07732034,  0.29285237, -0.11602996,  0.45477544,  0.22438195,
#         0.09535045,  0.27191729,  0.09269764, -0.2135845 ,  0.01302444])

# %% [markdown]
# Plot the distribution of sample means

# %%
ax = sns.distplot(sample_means)
ax.axvline(mydist.ppf(0.5), color='C3', lw=2, label='most likely value in mydist')
plt.gcf().set_dpi(150)
plt.legend(bbox_to_anchor=(1, 1), borderaxespad=0.0)

# %% [markdown]
# ### Sampling distribution of the mean for multiple distribution shapes

# %%
df = faker.utils.stacked_from_function(
    func=getattr(dist_func, 'rvs'),
    func_seed_arg='random_state',
    apply_func=np.mean,
    param_grid=dict(size=[sample_size], **shape_grid),
    col_names=['sample_mean'],
    iters=n_samples,
    seed=12345)
df.head()
# Out:
#    sample_mean  loc  scale  size
# 0    20.386602   20      5    16
# 1    21.464262   20      5    16
# 2    19.419850   20      5    16
# 3    22.273877   20      5    16
# 4    21.121910   20      5    16

# %%
grid = snsexts.plots.distplot(a='sample_mean',
                       data=df,
                       row=row,
                       col=col,
                       sharex=sharex,
                       sharey=sharey,
                       distplot_kws={'hist': True, 'kde': kde})

retoucher = retouch.grid.FacetGridRetoucher(grid)
retoucher.fig.set_dpi(300)
retoucher.fig.set_title(title='Sampling distribution of the mean for multiple distribution shapes', y=1.05)

# %% [markdown]
# ### Sampling distribution of the mean for a single distribution shape but different sample sizes

# %%
df = faker.utils.stacked_from_function(
    func=getattr(dist_func, 'rvs'),
    func_seed_arg='random_state',
    apply_func=np.mean,
    param_grid=dict(size=[10, 30, 100, 300, 500, 1000],
                    **{k: [v] for k, v in default_shape_kws.items()}),
    col_names=['sample_mean'],
    iters=n_samples,
    seed=12345)
df.head()
# Out:
#    sample_mean  loc  scale  size
# 0     0.328409    0      1    10
# 1    -0.198032    0      1    10
# 2    -0.115563    0      1    10
# 3     0.486645    0      1    10
# 4     0.452168    0      1    10

# %%
grid = snsexts.plots.distplot(a='sample_mean',
                       data=df,
                       col='size',
                       col_wrap=3,
                       distplot_kws={'hist': True})

retoucher = retouch.grid.FacetGridRetoucher(grid)
retoucher.fig.set_dpi(300)
retoucher.fig.set_title(title='Sampling distribution of the mean for different sample sizes\nfor {}'.format(default_shape_kws), y=1.05)
