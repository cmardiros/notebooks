# %% [markdown]
# **Execution:**
#
# * Started: 2018-03-22 14:30:31 GMT
# * Ended: 2018-03-22 14:30:45 GMT
#
# **Duration:** 13.4 seconds.
#
# **Autogenerated from:** [scipy-distributions-rv-template.ipynb](in_path)

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy as np
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
import matplotlib as mpl
import seabornextends as snsexts
import faker
from faker import utils
from seabornextends import plots, retouch
from seabornextends.retouch import grid, ax, fig

# %%
sns.set_style('whitegrid')
mpl.rcParams['grid.color'] = '0.95'
mpl.rcParams['grid.alpha'] = 0.8
mpl.rcParams['font.family'] = 'Roboto Condensed'

# %% [markdown]
# # Develop intuitive understanding of common distributions

# %% [markdown]
# ## Parameters

# %%
# default parameters for this template
# (these are overriden during dynamic notebook execution)
dist_family = 'norm'
kind = 'continuous'

# default shape
default_shape_kws = {'loc': 0, 'scale': 1}

# grid of shapes
shape_grid = {
    'loc': [2, 4, 6],
    'scale': [3, 6, 9]
}

# for plotting
row = 'loc'
col = 'scale'
sharex = True
sharey = True
kde = True

# params for creating evenly spaced probabilities
LO_PROB = 0.001
HI_PROB = 0.999
n_prob_linspace = 1000

# common lo/hi probabilities
lo_p = 0.025
hi_p = 0.975

# list of common probabilities
common_probs = [0.01, 0.025, 0.05, 0.1, 0.4, 0.5, 0.6, 0.9, 0.95, 0.975, 0.99]

# %%
# cell inserted during automated execution with new args.
dist_family = 'norm'
kind = 'continuous'
default_shape_kws = {'loc': 0, 'scale': 1}
shape_grid = {'loc': [20, 30, 40], 'scale': [5, 10, 15]}
row = 'loc'
col = 'scale'

# %% [markdown]
# ## Get distribution function from scipy

# %%
dist_func = getattr(stats, dist_family)
dist_func

# %% [markdown]
# ## Compare this distribution in different shapes

# %% [markdown]
# Generate random samples from this distribution in different shapes (of size `iters` each):

# %%
df = faker.utils.stacked_from_function(func=getattr(dist_func, 'rvs'),
                                       param_grid=shape_grid,
                                       col_names=['random_value'],
                                       iters=10000,
                                       seed=12345)

# %%
grid = snsexts.plots.distplot(a='random_value',
                              data=df,
                              row=row,
                              col=col,
                              sharex=sharex,
                              sharey=sharey,
                              distplot_kws={'hist': True, 'kde': kde})
retoucher = retouch.grid.FacetGridRetoucher(grid)
retoucher.fig.set_dpi(300)

# %% [markdown]
# ## Instantiate a distribution

# %%
mydist = dist_func(**default_shape_kws)
mydist

# %% [markdown]
# In order to make this notebook work for both continuous and discrete distributions
# we create a common alias for PDF/PMF.

# %%
if kind == 'continuous':
    pf = mydist.pdf
    pfname = 'PDF'
    pfdesc = 'Probability Density Function'
    logpf = mydist.logpdf
    logpfname = 'Log PDF'
    logpfdesc = 'Log Probability Density Function'
    
elif kind == 'discrete':
    pf = mydist.pmf
    pfname = 'PMF'
    pfdesc = 'Probability Mass Function'
    
    logpf = mydist.logpmf
    logpfname = 'Log PMF'
    logpfdesc = 'Log Probability Mass Function'

# %% [markdown]
# Moments:

# %%
mean, var, skew, kurt = mydist.stats(moments='mvsk')
print("mean: ", mean)
print("var: ", var)
print("skew: ", skew)
print("kurt: ", kurt)
# Out:
# mean:  0.0
# var:  1.0
# skew:  0.0
# kurt:  0.0

# %% [markdown]
# ### Generate evenly spaced probabilities

# %% [markdown]
# Generate a list of evenly spaced probabilities:

# %%
prob_linspace = np.linspace(start=LO_PROB, stop=HI_PROB, num=n_prob_linspace)
prob_linspace[0:5], prob_linspace[-5:]
# Out:
# (array([0.001   , 0.001999, 0.002998, 0.003997, 0.004996]),
#  array([0.995004, 0.996003, 0.997002, 0.998001, 0.999   ]))

# %% [markdown]
# Get _quantiles_ corresponding to probabilities in `prob_linspace`

# %%
quantiles = mydist.ppf(prob_linspace)
quantiles[0:5], quantiles[-5:]
# Out:
# (array([-3.09023231, -2.87831966, -2.74800027, -2.65232337, -2.57610631]),
#  array([2.57610631, 2.65232337, 2.74800027, 2.87831966, 3.09023231]))

# %% [markdown]
# ## Generate random numbers from this distribution

# %%
rands = mydist.rvs(size=100000)
rands[0:5]
# Out:
# array([-1.00332776, -1.11199887,  1.06093813, -0.53624707, -0.55836748])

# %%
ax = sns.distplot(rands)
ax.axvline(np.mean(rands), label='mean: {0:.5f}'.format(np.mean(rands)), color='C3')
ax.axvline(np.median(rands), label='median: {0:.5f}'.format(np.median(rands)), color='C3', ls='dashed')
ax.axvline(mydist.mean(), label='mean of frozen dist: {0:.5f}'.format(mydist.mean()), color='C4')
plt.legend(bbox_to_anchor=(1, 1), loc='upper left')
plt.gcf().set_dpi(150)

# %% [markdown]
# ## Probabilty Density Function / Probability Mass Function

# %% [markdown]
# Take a `quantile` as input and return a _point evaluated_ `probability`.
#
# **NOTE**: for normal distribution with mean different to 0 and std different to 1, quantile is a value x (e.g. 1160) _and not_ the standardised version of that value.
#
# To be a **valid pdf/pmf**, a function must satisfy:
# * It must be larger than or equal to zero everywhere (a value must be possible).
# * The total area under it must be one.

# %%
probs = common_probs
for p in probs:
    print("{n} evaluated at quantile {q:.3f} -- which marks {cdf:.3f} CDF probability in distribution -- is {logpf:.3f} (evaluated at that point only).".format(
        q=mydist.ppf(p),
        n=pfname,
        cdf=mydist.cdf(mydist.ppf(p)),
        logpf=pf(mydist.ppf(p))))
# Out:
# PDF evaluated at quantile -2.326 -- which marks 0.010 CDF probability in distribution -- is 0.027 (evaluated at that point only).
# PDF evaluated at quantile -1.960 -- which marks 0.025 CDF probability in distribution -- is 0.058 (evaluated at that point only).
# PDF evaluated at quantile -1.645 -- which marks 0.050 CDF probability in distribution -- is 0.103 (evaluated at that point only).
# PDF evaluated at quantile -1.282 -- which marks 0.100 CDF probability in distribution -- is 0.175 (evaluated at that point only).
# PDF evaluated at quantile -0.253 -- which marks 0.400 CDF probability in distribution -- is 0.386 (evaluated at that point only).
# PDF evaluated at quantile 0.000 -- which marks 0.500 CDF probability in distribution -- is 0.399 (evaluated at that point only).
# PDF evaluated at quantile 0.253 -- which marks 0.600 CDF probability in distribution -- is 0.386 (evaluated at that point only).
# PDF evaluated at quantile 1.282 -- which marks 0.900 CDF probability in distribution -- is 0.175 (evaluated at that point only).
# PDF evaluated at quantile 1.645 -- which marks 0.950 CDF probability in distribution -- is 0.103 (evaluated at that point only).
# PDF evaluated at quantile 1.960 -- which marks 0.975 CDF probability in distribution -- is 0.058 (evaluated at that point only).
# PDF evaluated at quantile 2.326 -- which marks 0.990 CDF probability in distribution -- is 0.027 (evaluated at that point only).

# %% [markdown]
# We evaluate a list of quantiles and return their **probability density function estimate** (point-estimates only).
#
# In the standard normal, quantiles at the extremes of the distribution have very low probability while quantiles in the middle of the distribution have very high probability.

# %%
estimates = pf(mydist.ppf(prob_linspace))

# %%
mydist.ppf(prob_linspace)[0:5], estimates[0:5]
# Out:
# (array([-3.09023231, -2.87831966, -2.74800027, -2.65232337, -2.57610631]),
#  array([0.00336709, 0.00633731, 0.00914369, 0.01183909, 0.01444943]))

# %%
mydist.ppf(prob_linspace)[-5:], estimates[-5:]
# Out:
# (array([2.57610631, 2.65232337, 2.74800027, 2.87831966, 3.09023231]),
#  array([0.01444943, 0.01183909, 0.00914369, 0.00633731, 0.00336709]))

# %%
# plot
fig, ax = plt.subplots(1, 1)

# function
ax.plot(mydist.ppf(prob_linspace),
        pf(mydist.ppf(prob_linspace)),
        lw=3,
        alpha=0.6,
        color='black',
        label='{0} {1}'.format(dist_family, pfname))

# lo_p

ax.vlines(x=mydist.ppf(lo_p),
          ymin=0,
          ymax=pf(mydist.ppf(lo_p)),
          colors='C3',
          alpha=1,
          label='point probability estimate for quantile {q:.3f} is {p:.3f}'.format(p=pf(mydist.ppf(lo_p)),
                                                                                    q=mydist.ppf(lo_p)))

ax.fill_between(x=mydist.ppf(prob_linspace[np.where((prob_linspace >= LO_PROB) &
                                                    (prob_linspace <= lo_p))]),
                y1=pf(mydist.ppf(prob_linspace[np.where((prob_linspace >= LO_PROB) &
                                                        (prob_linspace <= lo_p))])),
                color='C3',
                alpha=0.1)

# hi_p
ax.vlines(x=mydist.ppf(hi_p),
          ymin=0,
          ymax=pf(mydist.ppf(hi_p)),
          color='C0',
          alpha=1,
          label='point probability estimate for quantile {q:.3f} is {p:.3f}'.format(p=pf(mydist.ppf(hi_p)),
                                                                                    q=mydist.ppf(hi_p)))


ax.fill_between(x=mydist.ppf(prob_linspace[np.where((prob_linspace >= hi_p) &
                                                    (prob_linspace <= HI_PROB))]),
                y1=pf(mydist.ppf(prob_linspace[np.where((prob_linspace >= hi_p) &
                                                        (prob_linspace <= HI_PROB))])),
                color='C0',
                alpha=0.1)

plt.legend(bbox_to_anchor=(1, 1), loc='upper left')
plt.gcf().set_dpi(150)

# %% [markdown]
# ## Log Probabilty Density Function / Probability Mass Function

# %%
probs = common_probs
for p in probs:
    print("{n} evaluated at quantile {q:.3f} -- which marks {cdf:.3f} CDF probability in distribution -- is {logpf:.3f} (evaluated at that point only).".format(
        q=mydist.ppf(p),
        n=logpfname,
        cdf=mydist.cdf(mydist.ppf(p)),
        logpf=logpf(mydist.ppf(p))))
# Out:
# Log PDF evaluated at quantile -2.326 -- which marks 0.010 CDF probability in distribution -- is -3.625 (evaluated at that point only).
# Log PDF evaluated at quantile -1.960 -- which marks 0.025 CDF probability in distribution -- is -2.840 (evaluated at that point only).
# Log PDF evaluated at quantile -1.645 -- which marks 0.050 CDF probability in distribution -- is -2.272 (evaluated at that point only).
# Log PDF evaluated at quantile -1.282 -- which marks 0.100 CDF probability in distribution -- is -1.740 (evaluated at that point only).
# Log PDF evaluated at quantile -0.253 -- which marks 0.400 CDF probability in distribution -- is -0.951 (evaluated at that point only).
# Log PDF evaluated at quantile 0.000 -- which marks 0.500 CDF probability in distribution -- is -0.919 (evaluated at that point only).
# Log PDF evaluated at quantile 0.253 -- which marks 0.600 CDF probability in distribution -- is -0.951 (evaluated at that point only).
# Log PDF evaluated at quantile 1.282 -- which marks 0.900 CDF probability in distribution -- is -1.740 (evaluated at that point only).
# Log PDF evaluated at quantile 1.645 -- which marks 0.950 CDF probability in distribution -- is -2.272 (evaluated at that point only).
# Log PDF evaluated at quantile 1.960 -- which marks 0.975 CDF probability in distribution -- is -2.840 (evaluated at that point only).
# Log PDF evaluated at quantile 2.326 -- which marks 0.990 CDF probability in distribution -- is -3.625 (evaluated at that point only).

# %%
estimates = logpf(mydist.ppf(prob_linspace))

# %%
mydist.ppf(prob_linspace)[0:5], estimates[0:5]
# Out:
# (array([-3.09023231, -2.87831966, -2.74800027, -2.65232337, -2.57610631]),
#  array([-5.69370639, -5.06130056, -4.69469127, -4.43634817, -4.23710039]))

# %%
mydist.ppf(prob_linspace)[-5:], estimates[-5:]
# Out:
# (array([2.57610631, 2.65232337, 2.74800027, 2.87831966, 3.09023231]),
#  array([-4.23710039, -4.43634817, -4.69469127, -5.06130056, -5.69370639]))

# %%
# plot
fig, ax = plt.subplots(1, 1)

# function
ax.plot(mydist.ppf(prob_linspace),
        logpf(mydist.ppf(prob_linspace)),
        lw=3,
        alpha=0.6,
        color='black',
        label='{0} {1}'.format(dist_family, pfname))

# lo_p

ax.vlines(x=mydist.ppf(lo_p),
          ymin=0,
          ymax=logpf(mydist.ppf(lo_p)),
          colors='C3',
          alpha=1,
          label='point probability estimate for quantile {q:.3f} is {p:.3f}'.format(p=logpf(mydist.ppf(lo_p)),
                                                                                    q=mydist.ppf(lo_p)))

ax.fill_between(x=mydist.ppf(prob_linspace[np.where((prob_linspace >= LO_PROB) &
                                                    (prob_linspace <= lo_p))]),
                y1=logpf(mydist.ppf(prob_linspace[np.where((prob_linspace >= LO_PROB) &
                                                        (prob_linspace <= lo_p))])),
                color='C3',
                alpha=0.1)

# hi_p
ax.vlines(x=mydist.ppf(hi_p),
          ymin=0,
          ymax=logpf(mydist.ppf(hi_p)),
          color='C0',
          alpha=1,
          label='point probability estimate for quantile {q:.3f} is {p:.3f}'.format(p=logpf(mydist.ppf(hi_p)),
                                                                                    q=mydist.ppf(hi_p)))


ax.fill_between(x=mydist.ppf(prob_linspace[np.where((prob_linspace >= hi_p) &
                                                    (prob_linspace <= HI_PROB))]),
                y1=logpf(mydist.ppf(prob_linspace[np.where((prob_linspace >= hi_p) &
                                                        (prob_linspace <= HI_PROB))])),
                color='C0',
                alpha=0.1)

plt.legend(bbox_to_anchor=(1, 1), loc='upper left')
plt.gcf().set_dpi(150)

# %% [markdown]
# ## PPF (Percent Point Function or Quantile Function)

# %% [markdown]
# Take a _lower tail_ `probability` as input and return a `quantile` (inverse of `CDF`).
#
# It answers questions such as `What is the value below which 97.5% of distribution falls under?`

# %%
probs = [0.025, 0.5, 0.975]
for p in probs:
     print("Quantile corresponding to {p} lower tail probability is {q:.3f} ({p:.1%} of values are lower than or equal to {q:.3f})".format(
         p=p,
         q=mydist.ppf(p)))
# Out:
# Quantile corresponding to 0.025 lower tail probability is -1.960 (2.5% of values are lower than or equal to -1.960)
# Quantile corresponding to 0.5 lower tail probability is 0.000 (50.0% of values are lower than or equal to 0.000)
# Quantile corresponding to 0.975 lower tail probability is 1.960 (97.5% of values are lower than or equal to 1.960)

# %% [markdown]
# Calculate quantiles corresponding to list of _lower tail_ probabilities:

# %%
estimates = mydist.ppf(prob_linspace)

# %%
prob_linspace[0:5], estimates[0:5]
# Out:
# (array([0.001   , 0.001999, 0.002998, 0.003997, 0.004996]),
#  array([-3.09023231, -2.87831966, -2.74800027, -2.65232337, -2.57610631]))

# %%
prob_linspace[-5:], estimates[-5:]
# Out:
# (array([0.995004, 0.996003, 0.997002, 0.998001, 0.999   ]),
#  array([2.57610631, 2.65232337, 2.74800027, 2.87831966, 3.09023231]))

# %% [markdown]
# Quantiles of common lower tail probabilities:

# %%
probs = common_probs
for p in probs:
     print("Quantile corresponding to {p} lower tail probability is {q:.3f} ({p:.1%} of values are lower than or equal to {q:.3f})".format(
         p=p,
         q=mydist.ppf(p)))
# Out:
# Quantile corresponding to 0.01 lower tail probability is -2.326 (1.0% of values are lower than or equal to -2.326)
# Quantile corresponding to 0.025 lower tail probability is -1.960 (2.5% of values are lower than or equal to -1.960)
# Quantile corresponding to 0.05 lower tail probability is -1.645 (5.0% of values are lower than or equal to -1.645)
# Quantile corresponding to 0.1 lower tail probability is -1.282 (10.0% of values are lower than or equal to -1.282)
# Quantile corresponding to 0.4 lower tail probability is -0.253 (40.0% of values are lower than or equal to -0.253)
# Quantile corresponding to 0.5 lower tail probability is 0.000 (50.0% of values are lower than or equal to 0.000)
# Quantile corresponding to 0.6 lower tail probability is 0.253 (60.0% of values are lower than or equal to 0.253)
# Quantile corresponding to 0.9 lower tail probability is 1.282 (90.0% of values are lower than or equal to 1.282)
# Quantile corresponding to 0.95 lower tail probability is 1.645 (95.0% of values are lower than or equal to 1.645)
# Quantile corresponding to 0.975 lower tail probability is 1.960 (97.5% of values are lower than or equal to 1.960)
# Quantile corresponding to 0.99 lower tail probability is 2.326 (99.0% of values are lower than or equal to 2.326)

# %%
# plot
fig, ax = plt.subplots(1, 1)

# function
ax.plot(mydist.ppf(prob_linspace),
        prob_linspace,
        lw=3,
        alpha=0.6,
        color='black',
        label='{0} ppf'.format(dist_family))

# lo_p
ax.vlines(x=mydist.ppf(lo_p),
          ymin=0,
          ymax=lo_p,
          colors='C3',
          alpha=1,
          label='quantile for which {p:.1%} values are likely to be lower than or equal to is {q:.3f}'.format(
              p=lo_p,
              q=mydist.ppf(lo_p)))




ax.fill_between(x=mydist.ppf(prob_linspace[np.where((prob_linspace >= LO_PROB) &
                                                    (prob_linspace <= lo_p))]),
                y1=mydist.cdf(mydist.ppf(prob_linspace[np.where((prob_linspace >= LO_PROB) &
                                                                (prob_linspace <= lo_p))])),
                color='C3',
                alpha=0.1)

# hi_p
ax.vlines(x=mydist.ppf(hi_p),
          ymin=0,
          ymax=hi_p,
          color='C0',
          alpha=1,
          label='quantile for which {p:.1%} values are likely to be lower than or equal to is {q:.3f}'.format(
              p=hi_p,
              q=mydist.ppf(hi_p)))




ax.fill_between(x=mydist.ppf(prob_linspace[np.where((prob_linspace >= LO_PROB) &
                                                    (prob_linspace <= hi_p))]),
                y1=mydist.cdf(mydist.ppf(prob_linspace[np.where((prob_linspace >= LO_PROB) &
                                                                (prob_linspace <= hi_p))])),
                color='C0',
                alpha=0.1)

plt.legend(bbox_to_anchor=(1, 1), loc='upper left')
plt.gcf().set_dpi(150)

# %% [markdown]
# ## ISF (Inverse Survival Function)

# %% [markdown]
# Take an _upper tail_ `probability` as input and returns a `quantile` (inverse of `SF`).
#
# It answers questions such as `What is the value above which 97.5% of distribution falls above?`

# %%
probs = [0.025, 0.5, 0.975]
for p in probs:
     print("Quantile corresponding to {p} upper tail probability is {q:.3f} ({p:.1%} of values are greater than {q:.3f})".format(
         p=p,
         q=mydist.isf(p)))
# Out:
# Quantile corresponding to 0.025 upper tail probability is 1.960 (2.5% of values are greater than 1.960)
# Quantile corresponding to 0.5 upper tail probability is 0.000 (50.0% of values are greater than 0.000)
# Quantile corresponding to 0.975 upper tail probability is -1.960 (97.5% of values are greater than -1.960)

# %% [markdown]
# Calculate quantiles corresponding to list of _upper tail_ probabilities:

# %%
estimates = mydist.isf(prob_linspace)

# %%
prob_linspace[0:5], estimates[0:5]
# Out:
# (array([0.001   , 0.001999, 0.002998, 0.003997, 0.004996]),
#  array([3.09023231, 2.87831966, 2.74800027, 2.65232337, 2.57610631]))

# %%
prob_linspace[-5:], estimates[-5:]
# Out:
# (array([0.995004, 0.996003, 0.997002, 0.998001, 0.999   ]),
#  array([-2.57610631, -2.65232337, -2.74800027, -2.87831966, -3.09023231]))

# %% [markdown]
# Quantiles of common upper tail probabilities:

# %%
probs = common_probs
for p in probs:
     print("Quantile corresponding to {p} upper tail probability is {q:.3f} ({p:.1%} of values are greater than {q:.3f})".format(
         p=p,
         q=mydist.isf(p)))
# Out:
# Quantile corresponding to 0.01 upper tail probability is 2.326 (1.0% of values are greater than 2.326)
# Quantile corresponding to 0.025 upper tail probability is 1.960 (2.5% of values are greater than 1.960)
# Quantile corresponding to 0.05 upper tail probability is 1.645 (5.0% of values are greater than 1.645)
# Quantile corresponding to 0.1 upper tail probability is 1.282 (10.0% of values are greater than 1.282)
# Quantile corresponding to 0.4 upper tail probability is 0.253 (40.0% of values are greater than 0.253)
# Quantile corresponding to 0.5 upper tail probability is 0.000 (50.0% of values are greater than 0.000)
# Quantile corresponding to 0.6 upper tail probability is -0.253 (60.0% of values are greater than -0.253)
# Quantile corresponding to 0.9 upper tail probability is -1.282 (90.0% of values are greater than -1.282)
# Quantile corresponding to 0.95 upper tail probability is -1.645 (95.0% of values are greater than -1.645)
# Quantile corresponding to 0.975 upper tail probability is -1.960 (97.5% of values are greater than -1.960)
# Quantile corresponding to 0.99 upper tail probability is -2.326 (99.0% of values are greater than -2.326)

# %%
# plot
fig, ax = plt.subplots(1, 1)

# function
ax.plot(mydist.isf(prob_linspace),
        prob_linspace,
        lw=3,
        alpha=0.6,
        color='black',
        label='{0} isf'.format(dist_family))

# hi_p
ax.vlines(x=mydist.isf(hi_p),
          ymin=0,
          ymax=hi_p,
          color='C3',
          alpha=1,
          label='quantile for which {p:.1%} values are likely to be greater than is {q:.3f}'.format(
              p=hi_p,
              q=mydist.isf(hi_p)))


ax.fill_between(x=mydist.ppf(prob_linspace[np.where((prob_linspace >= LO_PROB) &
                                                    (prob_linspace <= hi_p))]),
                y1=mydist.sf(mydist.ppf(prob_linspace[np.where((prob_linspace >= LO_PROB) &
                                                               (prob_linspace <= hi_p))])),
                color='C3',
                alpha=0.1)

# lo_p
ax.vlines(x=mydist.isf(lo_p),
          ymin=0,
          ymax=lo_p,
          colors='C0',
          alpha=1,
          label='quantile for which {p:.1%} values are likely to be greater than is {q:.3f}'.format(
              p=lo_p,
              q=mydist.isf(lo_p)))



ax.fill_between(x=mydist.ppf(prob_linspace[np.where((prob_linspace >= LO_PROB) &
                                                    (prob_linspace <= lo_p))]),
                y1=mydist.sf(mydist.ppf(prob_linspace[np.where((prob_linspace >= LO_PROB) &
                                                               (prob_linspace <= lo_p))])),
                color='C0',
                alpha=0.1)


plt.legend(bbox_to_anchor=(1, 1), loc='upper left')
plt.gcf().set_dpi(150)

# %% [markdown]
# ## CDF (Cumulative Density Function)

# %% [markdown]
# Take a `quantile` as input and return a `probability`.
#
# CDF returns the `probability` that the random variable is *less than or equal to some value* (a `quantile`)

# %%
probs = common_probs
for p in probs:
    print("Probability that a random variable is *less or equal than* {q:.3f} quantile is {cdf:.3f}.".format(
        q=mydist.ppf(p),
        cdf=mydist.cdf(mydist.ppf(p))))
# Out:
# Probability that a random variable is *less or equal than* -2.326 quantile is 0.010.
# Probability that a random variable is *less or equal than* -1.960 quantile is 0.025.
# Probability that a random variable is *less or equal than* -1.645 quantile is 0.050.
# Probability that a random variable is *less or equal than* -1.282 quantile is 0.100.
# Probability that a random variable is *less or equal than* -0.253 quantile is 0.400.
# Probability that a random variable is *less or equal than* 0.000 quantile is 0.500.
# Probability that a random variable is *less or equal than* 0.253 quantile is 0.600.
# Probability that a random variable is *less or equal than* 1.282 quantile is 0.900.
# Probability that a random variable is *less or equal than* 1.645 quantile is 0.950.
# Probability that a random variable is *less or equal than* 1.960 quantile is 0.975.
# Probability that a random variable is *less or equal than* 2.326 quantile is 0.990.

# %% [markdown]
# We evaluate a list of quantiles and return their **cumulative density function** probability.

# %%
estimates = mydist.cdf(mydist.ppf(prob_linspace))

# %%
mydist.ppf(prob_linspace)[0:5], estimates[0:5]
# Out:
# (array([-3.09023231, -2.87831966, -2.74800027, -2.65232337, -2.57610631]),
#  array([0.001   , 0.001999, 0.002998, 0.003997, 0.004996]))

# %%
mydist.ppf(prob_linspace)[-5:], estimates[-5:]
# Out:
# (array([2.57610631, 2.65232337, 2.74800027, 2.87831966, 3.09023231]),
#  array([0.995004, 0.996003, 0.997002, 0.998001, 0.999   ]))

# %%
# plot
fig, ax = plt.subplots(1, 1)

# function
ax.plot(mydist.ppf(prob_linspace),
        mydist.cdf(mydist.ppf(prob_linspace)),
        lw=3,
        alpha=0.6,
        color='black',
        label='{0} cdf'.format(dist_family))

# lo_p

ax.vlines(x=mydist.ppf(lo_p),
          ymin=0,
          ymax=mydist.cdf(mydist.ppf(lo_p)),
          colors='C3',
          alpha=1,
          label='probability that a random variable\n from this distribution is lower than quantile {q:.3f} is {p:.1%}'.format(
              p=mydist.cdf(mydist.ppf(lo_p)),
              q=mydist.ppf(lo_p)))



ax.fill_between(x=mydist.ppf(prob_linspace[np.where((prob_linspace >= LO_PROB) &
                                                    (prob_linspace <= lo_p))]),
                y1=mydist.cdf(mydist.ppf(prob_linspace[np.where((prob_linspace >= LO_PROB) &
                                                                (prob_linspace <= lo_p))])),
                color='C3',
                alpha=0.1)

# hi_p
ax.vlines(x=mydist.ppf(hi_p),
          ymin=0,
          ymax=mydist.cdf(mydist.ppf(hi_p)),
          color='C0',
          alpha=1,
          label='probability that a random variable\n from this distribution is lower than quantile {q:.3f} is {p:.1%}'.format(
              p=mydist.cdf(mydist.ppf(hi_p)),
              q=mydist.ppf(hi_p)))



ax.fill_between(x=mydist.ppf(prob_linspace[np.where((prob_linspace >= LO_PROB) &
                                                    (prob_linspace <= hi_p))]),
                y1=mydist.cdf(mydist.ppf(prob_linspace[np.where((prob_linspace >= LO_PROB) &
                                                                (prob_linspace <= hi_p))])),
                color='C0',
                alpha=0.1)

plt.legend(bbox_to_anchor=(1, 1), loc='upper left')
plt.gcf().set_dpi(150)

# %% [markdown]
# ## SF (Survival Function)

# %% [markdown]
# Take a `quantile` as input and return a `probability`.
#
# SF returns the `probability` that the random variable is *greater than some value* (a `quantile`)

# %%
probs = common_probs
for p in probs:
    print("Probability that a random variable is *greater than* {q:.3f} quantile is {sf:.3f}.".format(
        q=mydist.ppf(p),
        sf=mydist.sf(mydist.ppf(p))))
# Out:
# Probability that a random variable is *greater than* -2.326 quantile is 0.990.
# Probability that a random variable is *greater than* -1.960 quantile is 0.975.
# Probability that a random variable is *greater than* -1.645 quantile is 0.950.
# Probability that a random variable is *greater than* -1.282 quantile is 0.900.
# Probability that a random variable is *greater than* -0.253 quantile is 0.600.
# Probability that a random variable is *greater than* 0.000 quantile is 0.500.
# Probability that a random variable is *greater than* 0.253 quantile is 0.400.
# Probability that a random variable is *greater than* 1.282 quantile is 0.100.
# Probability that a random variable is *greater than* 1.645 quantile is 0.050.
# Probability that a random variable is *greater than* 1.960 quantile is 0.025.
# Probability that a random variable is *greater than* 2.326 quantile is 0.010.

# %% [markdown]
# We evaluate a list of quantiles and return their **survival function** probability.

# %%
estimates = mydist.sf(mydist.ppf(prob_linspace))

# %%
mydist.ppf(prob_linspace)[0:5], estimates[0:5]
# Out:
# (array([-3.09023231, -2.87831966, -2.74800027, -2.65232337, -2.57610631]),
#  array([0.999   , 0.998001, 0.997002, 0.996003, 0.995004]))

# %%
mydist.ppf(prob_linspace)[-5:], estimates[-5:]
# Out:
# (array([2.57610631, 2.65232337, 2.74800027, 2.87831966, 3.09023231]),
#  array([0.004996, 0.003997, 0.002998, 0.001999, 0.001   ]))

# %%
# plot
fig, ax = plt.subplots(1, 1)

# function
ax.plot(mydist.ppf(prob_linspace),
        mydist.sf(mydist.ppf(prob_linspace)),
        lw=3,
        alpha=0.6,
        color='black',
        label='{0} sf'.format(dist_family))

# lo_p

ax.vlines(x=mydist.ppf(lo_p),
          ymin=0,
          ymax=mydist.sf(mydist.ppf(lo_p)),
          colors='C3',
          alpha=1,
          label='probability that a random variable\n from this distribution is greater than quantile {q:.3f} is {p:.1%}'.format(
              p=mydist.sf(mydist.ppf(lo_p)),
              q=mydist.ppf(lo_p)))



ax.fill_between(x=mydist.ppf(prob_linspace[np.where((prob_linspace >= lo_p) &
                                                    (prob_linspace <= HI_PROB))]),
                y1=mydist.sf(mydist.ppf(prob_linspace[np.where((prob_linspace >= lo_p) &
                                                               (prob_linspace <= HI_PROB))])),
                color='C3',
                alpha=0.1)

# hi_p
ax.vlines(x=mydist.ppf(hi_p),
          ymin=0,
          ymax=mydist.sf(mydist.ppf(hi_p)),
          color='C0',
          alpha=1,
          label='probability that a random variable\n from this distribution is greater than quantile {q:.3f} is {p:.1%}'.format(
              p=mydist.sf(mydist.ppf(hi_p)),
              q=mydist.ppf(hi_p)))



ax.fill_between(x=mydist.ppf(prob_linspace[np.where((prob_linspace >= hi_p) &
                                                    (prob_linspace <= HI_PROB))]),
                y1=mydist.sf(mydist.ppf(prob_linspace[np.where((prob_linspace >= hi_p) &
                                                               (prob_linspace <= HI_PROB))])),
                color='C0',
                alpha=0.1)

plt.legend(bbox_to_anchor=(1, 1), loc='upper left')
plt.gcf().set_dpi(150)

# %% [markdown]
# ## Variance of sample means

# %% [markdown]
# We treat the sample mean as a random variable in itself which has its own distribution. Central limit theorem shows that the mean of this distribution converges towards the population mean from which we drew the sample as the sample size increases.

# %%
n_samples = 1000
sample_size = 16

# %% [markdown]
# ### Sampling distribution of the mean for a _single_ distribution shape

# %% [markdown]
# Draw `n_samples` random samples of size `sample_size`:

# %%
data = faker.utils.from_function(func=mydist.rvs,
                                 func_kws={'size': sample_size},
                                 func_seed_arg='random_state',
                                 iters=n_samples)

print("data.shape: ", data.shape)
data[0:2]
# Out:
# data.shape:  (1000, 16)
# array([[-1.05649838e+00, -6.58157905e-01, -2.59246832e-02,
#          1.53895705e-01, -5.41746537e-01,  3.21085307e-04,
#         -1.62712675e+00,  1.76983515e+00, -3.91806478e-01,
#          8.93882818e-01, -2.16928250e-01, -1.15734203e+00,
#         -1.38883015e+00,  3.87165553e-01,  2.51661011e-01,
#         -2.63380979e-01],
#        [ 4.01731705e-01, -6.76371146e-01,  4.40395147e-01,
#         -1.94661267e+00, -1.56644236e+00,  1.61405224e+00,
#          1.63203407e-01, -1.51366123e+00,  1.27597712e+00,
#         -6.16920092e-01, -1.17707399e+00, -1.83547847e+00,
#          5.99382821e-01,  4.76706043e-01,  1.15593312e+00,
#          1.18453880e-01]])

# %% [markdown]
# Calculate the mean for each sample drawn:

# %%
sample_means = np.mean(data, axis=1)
print("sample_means.shape: ", sample_means.shape)
sample_means[0:10]
# Out:
# sample_means.shape:  (1000,)
# array([-0.2419363 , -0.19292028, -0.01515994,  0.07013467,  0.2480738 ,
#         0.20834164,  0.02891709, -0.15262356, -0.44579564,  0.40482618])

# %% [markdown]
# Plot the distribution of sample means

# %%
ax = sns.distplot(sample_means)
ax.axvline(mydist.ppf(0.5), color='C3', lw=2, label='most likely value in mydist')
plt.gcf().set_dpi(150)
plt.legend(bbox_to_anchor=(1, 1), borderaxespad=0.0)

# %% [markdown]
# ### Sampling distribution of the mean for multiple distribution shapes

# %%
df = faker.utils.stacked_from_function(
    func=getattr(dist_func, 'rvs'),
    func_seed_arg='random_state',
    apply_func=np.mean,
    param_grid=dict(size=[sample_size], **shape_grid),
    col_names=['sample_mean'],
    iters=n_samples,
    seed=12345)
df.head()
# Out:
#    sample_mean  loc  scale  size
# 0    18.790318   20      5    16
# 1    19.035399   20      5    16
# 2    19.924200   20      5    16
# 3    20.350673   20      5    16
# 4    21.240369   20      5    16

# %%
grid = snsexts.plots.distplot(a='sample_mean',
                       data=df,
                       row=row,
                       col=col,
                       sharex=sharex,
                       sharey=sharey,
                       distplot_kws={'hist': True, 'kde': kde})

retoucher = retouch.grid.FacetGridRetoucher(grid)
retoucher.fig.set_dpi(300)
retoucher.fig.set_title(title='Sampling distribution of the mean for multiple distribution shapes', y=1.05)

# %% [markdown]
# ### Sampling distribution of the mean for a single distribution shape but different sample sizes

# %%
df = faker.utils.stacked_from_function(
    func=getattr(dist_func, 'rvs'),
    func_seed_arg='random_state',
    apply_func=np.mean,
    param_grid=dict(size=[10, 30, 100, 300, 500, 1000],
                    **{k: [v] for k, v in default_shape_kws.items()}),
    col_names=['sample_mean'],
    iters=n_samples,
    seed=12345)
df.head()
# Out:
#    sample_mean  loc  scale  size
# 0    -0.148333    0      1    10
# 1    -0.242465    0      1    10
# 2    -0.151293    0      1    10
# 3     0.014605    0      1    10
# 4     0.032093    0      1    10

# %%
grid = snsexts.plots.distplot(a='sample_mean',
                       data=df,
                       col='size',
                       col_wrap=3,
                       distplot_kws={'hist': True})

retoucher = retouch.grid.FacetGridRetoucher(grid)
retoucher.fig.set_dpi(300)
retoucher.fig.set_title(title='Sampling distribution of the mean for different sample sizes\nfor {}'.format(default_shape_kws), y=1.05)
